# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d_country = pd.read_csv("country_2023.csv")

d_country
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %%
d_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4798 entries, 0 to 4797
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4734 non-null   float64
#  1   High       4734 non-null   float64
#  2   Low        4734 non-null   float64
#  3   Close      4734 non-null   float64
#  4   Inflation  4434 non-null   float64
#  5   country    4798 non-null   object
#  6   ISO3       4798 non-null   object
#  7   date       4798 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 300.0+ KB

# %% [markdown]
# cambiar nombres de las columnas
# cambiar fechas de object a datetime

# %%
names_columns = ["open", "high", "low", "close", "inflation", "country", "iso3", "date"]
d_country.columns = names_columns
d_country
# Out:
#       open  high   low  close  inflation      country iso3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %%
#cambio de obect a datetime
d_country["date"] = pd.to_datetime(d_country["date"])
d_country
# Out:
#       open  high   low  close  inflation      country iso3       date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG 2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG 2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...        ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM 2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM 2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM 2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM 2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM 2023-10-01
#
# [4798 rows x 8 columns]

# %%
#eliminar duplicados
d_country=d_country.drop_duplicates()
d_country
# Out:
#       open  high   low  close  inflation      country iso3       date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG 2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG 2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG 2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...        ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM 2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM 2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM 2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM 2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM 2023-10-01
#
# [4798 rows x 8 columns]

# %%
d_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4798 entries, 0 to 4797
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open       4734 non-null   float64
#  1   high       4734 non-null   float64
#  2   low        4734 non-null   float64
#  3   close      4734 non-null   float64
#  4   inflation  4434 non-null   float64
#  5   country    4798 non-null   object
#  6   iso3       4798 non-null   object
#  7   date       4798 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 300.0+ KB

# %%
details = pd.read_csv("details_2023.csv")
details
# Out:
#                      country iso3  \
# 0                Afghanistan  AFG
# 1                    Burundi  BDI
# 2               Burkina Faso  BFA
# 3   Central African Republic  CAF
# 4                   Cameroon  CMR
# 5           Congo, Dem. Rep.  COD
# 6                Congo, Rep.  COG
# 7                Gambia, The  GMB
# 8              Guinea-Bissau  GNB
# 9                      Haiti  HTI
# 10                      Iraq  IRQ
# 11                   Lao PDR  LAO
# 12                   Lebanon  LBN
# 13                   Liberia  LBR
# 14                      Mali  MLI
# 15                   Myanmar  MMR
# 16                Mozambique  MOZ
# 17                     Niger  NER
# 18                   Nigeria  NGA
# 19                     Sudan  SDN
# 20                   Somalia  SOM
# 21               South Sudan  SSD
# 22      Syrian Arab Republic  SYR
# 23                      Chad  TCD
# 24               Yemen, Rep.  YEM
#
# ...

# %%
details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   country                                                 25 non-null     object
#  1   iso3                                                    25 non-null     object
#  2   components                                              25 non-null     object
#  3   currency                                                25 non-null     object
#  4   start_date_observations                                 25 non-null     object
#  5   end_date_observations                                   25 non-null     object
#  6   number_of_markets_modeled                               25 non-null     int64
#  7   number_of_markets_covered                               25 non-null     int64
# ...

# %% [markdown]
# cambiar start_date_observations y end_date_observations  de object a datetime

# %%
details["start_date_observations"] = pd.to_datetime(details["start_date_observations"], format="%b %Y")
details.head(1)
# Out:
#        country iso3                                         components  \
# 0  Afghanistan  AFG  Bread (1 KG, Index Weight = 1), Rice (Low Qual...
#
#   currency start_date_observations end_date_observations  \
# 0      AFN              2007-01-01              Sep 2023
#
#    number_of_markets_modeled  number_of_markets_covered  number_of_food_items  \
# 0                         40                         40                     3
#
#             number_of_observations_food  ...  \
# 0  bread: 2318, rice: 2701, wheat: 2682  ...
#
#   total_food_price_increase_since_start_date  \
# 0                                    167.97%
#
#   average_annualized_food_inflation maximum_food_drawdown  \
# 0                             6.06%               -40.67%
#
#   average_annualized_food_volatility  \
# 0                              7.93%
#
#   average_monthly_food_price_correlation_between_markets  \
# 0                                               0.62
#
# ...

# %%
details["end_date_observations"]=pd.to_datetime(details["end_date_observations"], format="%b %Y")
details
# Out:
#                      country iso3  \
# 0                Afghanistan  AFG
# 1                    Burundi  BDI
# 2               Burkina Faso  BFA
# 3   Central African Republic  CAF
# 4                   Cameroon  CMR
# 5           Congo, Dem. Rep.  COD
# 6                Congo, Rep.  COG
# 7                Gambia, The  GMB
# 8              Guinea-Bissau  GNB
# 9                      Haiti  HTI
# 10                      Iraq  IRQ
# 11                   Lao PDR  LAO
# 12                   Lebanon  LBN
# 13                   Liberia  LBR
# 14                      Mali  MLI
# 15                   Myanmar  MMR
# 16                Mozambique  MOZ
# 17                     Niger  NER
# 18                   Nigeria  NGA
# 19                     Sudan  SDN
# 20                   Somalia  SOM
# 21               South Sudan  SSD
# 22      Syrian Arab Republic  SYR
# 23                      Chad  TCD
# 24               Yemen, Rep.  YEM
#
# ...

# %%
details=details.drop_duplicates()
details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 23 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   country                                                 25 non-null     object
#  1   iso3                                                    25 non-null     object
#  2   components                                              25 non-null     object
#  3   currency                                                25 non-null     object
#  4   start_date_observations                                 25 non-null     datetime64[ns]
#  5   end_date_observations                                   25 non-null     datetime64[ns]
#  6   number_of_markets_modeled                               25 non-null     int64
#  7   number_of_markets_covered                               25 non-null     int64
# ...
